# %% [markdown]
# <a href="https://colab.research.google.com/github/yenanjing/mmEgo_Rev/blob/master/mmEgo_Rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Download the mmEgo repository.**

# %%
# !git clone https://github.com/yenanjing/mmEgo_Rev.git
# Out:
# Cloning into 'mmEgo_Rev'...
# remote: Enumerating objects: 19584, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 19584 (delta 47), reused 131 (delta 44), pack-reused 19450
# Receiving objects: 100% (19584/19584), 209.06 MiB | 37.90 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# Updating files: 100% (19233/19233), done.

# %% [markdown]
# **Test with pose estimation quantization results.**

# %%
run mmEgo_Rev/main.py --infer
# Out:
# data load end
# 835it [00:25, 32.41it/s]
# Average Joint Localization Error(cm): 3.8930572709905173
# Average UpperBody Joint Localization Error(cm): 3.506960633718325
# Average LowerBody Joint Localization Error(cm): 4.487460637855494
# Average Joint Rotation Error(°): 5.373521191459929
# Per Joint Localization Error(cm): [3.35896401 2.87159954 2.56156718 2.30499341 2.34240532 2.80574483
#  4.48291182 6.71322842 2.31875554 2.69027915 4.41610014 6.65199177
#  3.10610079 4.25527868 5.23275739 5.73541412 3.05397837 4.12012021
#  5.01141669 5.38461884 2.33597472]

# %% [markdown]
# **Test with pose estimation visualization results.**

# %%
run mmEgo_Rev/main.py --infer --vis
# Out:
# data load end
# 0it [00:00, ?it/s]
# 1it [01:09, 69.48s/it]
# 2it [02:19, 69.57s/it]

# %% [markdown]
# Train IMU_Net.

# %%
python main.py --train --network IMU_Net

# %% [markdown]
# Train Upper_Net.

# %%
python main.py --train --network Upper_Net

# %% [markdown]
# Train Lower_Net.

# %%
python main.py --train --network Lower_Net
